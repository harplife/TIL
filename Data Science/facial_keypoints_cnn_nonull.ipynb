# %% [markdown]
# <h1>Facial Keypoints Detection<span class="tocSkip"></span></h1>
#
#     a simple Convolutional Deep Neural Network model
#     for detecting facial keypoints,
#     such as location of location of eye brows, eyes, nose, and mouth.
#
# Link: https://www.kaggle.com/c/facial-keypoints-detection
#
# current result:
#
# ![face_keypoint_result](https://user-images.githubusercontent.com/44990492/58523201-82f0b480-81fe-11e9-9591-07870e847bde.PNG)

# %% [markdown]
# # Resource Monitor
#
# CPUMon
#
# download: https://www.downloadcrew.com/article/35114-cpumon
#
#     very simple lightweight graphical CPU monitor.
#     Good for keeping CPU and memory in check,
#     especially if training dataset is ridiculously big.
#     Standalone, no installation.
#
# GPU-Z
#
# download: https://www.techpowerup.com/download/techpowerup-gpu-z/
#
#     also simple and lightweight, monitors GPU sensors.
#     Good for keeping track of GPU usuage, especially memory,
#     considering GPU memory is rather small.
#     Standalone, no installation.
#     *** Tensorflow tends to allocate all the GPU memory,
#     unless otherwise directed, and there's no other way to
#     free the GPU memory until the python kernel is killed ***

# %%
import os

os.startfile(r'C:\STUDY\resource_monitor\CPUMon.exe')
os.startfile(r'C:\STUDY\resource_monitor\GPU-Z.exe')

# %% [markdown]
# # Data

# %% [markdown]
# ## import

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Data Processing
#
# note:
#
#     training data has a lot of NULL.
#     there are only couple thousands that has no null.
#     so, in order to fill the null values,
#     as silly as it may sound,
#     I've trained a model that uses four major points
#     (left, right eye center, nose, mouth center)
#     to predict other 11 keypoints..

# %%
df = pd.read_csv('../data/face/training_nonull.csv')
df.shape
# Out:
# (7000, 31)

# %%
# using parallel processing
# 10 threads
# to separate "image" section into var x
from joblib import Parallel, delayed

def format_img(x):
    return np.asarray([int(e) for e in x.split(' ')], dtype=np.uint8).reshape(96,96)

# ref: https://joblib.readthedocs.io/en/latest/parallel.html
with Parallel(n_jobs=10, verbose=1, prefer='threads') as ex:
    x = ex(delayed(format_img)(e) for e in df.Image)
    
x = np.stack(x)[..., None]
x.shape
# Out:
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 180 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=10)]: Done 430 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=10)]: Done 780 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=10)]: Done 1230 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=10)]: Done 1780 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=10)]: Done 2430 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=10)]: Done 3180 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=10)]: Done 4030 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=10)]: Done 4980 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=10)]: Done 6030 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=10)]: Done 7000 out of 7000 | elapsed:   19.5s finished
# (7000, 96, 96, 1)

# %%
y = df.iloc[:, :-1].values
y.shape
# Out:
# (7000, 30)

# %%
# uses matplotlib to graph picture based on "image" data
def show(x, y=None):
    plt.imshow(x[..., 0], "gray")
    # plots y (label) data on top
    if y is not None:
        points = np.vstack(np.split(y, 15)).T
        plt.plot(points[0], points[1], 'o', color='yellow')
        
    plt.axis('off')

# %%
sample_idx = np.random.choice(len(x))    
show(x[sample_idx], y[sample_idx])

# %% [markdown]
# ## Training & Validaiton Dataset SPLIT

# %%
# separate training dataset, validation dataset
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# x data train set, x data validation set
x_train.shape, x_val.shape
# Out:
# ((5600, 96, 96, 1), (1400, 96, 96, 1))

# %%
# y data train set, y data validation set
y_train.shape, y_val.shape
# Out:
# ((5600, 30), (1400, 30))

# %% [markdown]
# ## Training Dataset Standardization
#
# refer to: https://maristie.com/blog/differences-between-normalization-standardization-and-regularization/

# %%
# x datasets reshaping for standardization
x_train_norm=x_train[:,:,:,:]
x_val_norm=x_val[:,:,:,:]
x_train_norm=x_train_norm.reshape([5600,96*96,1])
x_val_norm=x_val_norm.reshape([1400,96*96,1])

# %%
# prepare for standardization
mu=x_train_norm.mean()
sigma=x_train_norm.std()
mu, sigma
# Out:
# (124.91668443467881, 59.22537473444983)

# %%
# standardize
x_train_norm=(x_train_norm - mu)/sigma
x_val_norm=(x_val_norm - mu)/sigma

# %%
# x training dataset shape, mean, std
x_train_norm.shape, x_train_norm.mean(), x_train_norm.std()
# Out:
# ((5600, 9216, 1), 8.250895557611084e-17, 0.9999999999999992)

# %%
# x validation dataset shape, mean, std
x_val_norm.shape, x_val_norm.mean(), x_val_norm.std()
# Out:
# ((1400, 9216, 1), 0.000900799872987806, 1.0078569302644664)

# %%
# reshaping x datasets
x_train_norm=x_train_norm.reshape([5600,96,96,1])
x_val_norm=x_val_norm.reshape([1400,96,96,1])

x_train_norm.shape, x_val_norm.shape
# Out:
# ((5600, 96, 96, 1), (1400, 96, 96, 1))

# %% [markdown]
# ### standardization Result

# %%
print("{} is normalized to {}".format(x_train[0][0][0][0], x_train_norm[0][0][0][0]))
print("{} is normalized to {}".format(x_train[0][0][90][0], x_train_norm[0][0][90][0]))
# Out:
# 200 is normalized to 1.2677558546817806
# 209 is normalized to 1.41971774669772

# %%
# checking if standardization worked properly
# show img of standardized x_train dataset
sample_idx = np.random.choice(len(x_train_norm))
show(x_train_norm[sample_idx], y_train[sample_idx])

# %%
# there shouldn't be any difference
# show img of raw x_train dataset
show(x_train[sample_idx], y_train[sample_idx])

# %% [markdown]
# # Model
#
# BATCH NORMALIZATION:
#
# https://www.dlology.com/blog/one-simple-trick-to-train-keras-model-faster-with-batch-normalization/
#
#
# Conv2d:
#
# https://www.programcreek.com/python/example/89658/keras.layers.Conv2D

# %% [markdown]
# ## KERAS import

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, AvgPool2D, BatchNormalization, Dropout
from keras.optimizers import Adam
from keras import regularizers
from keras.callbacks import ReduceLROnPlateau
from keras.models import load_model
from keras.callbacks import CSVLogger
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## GPU availability check

# %%
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
# Out:
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 5765519967862494013
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 600936448
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 16993169244061913759
# physical_device_desc: "device: 0, name: GeForce GT 720, pci bus id: 0000:01:00.0, compute capability: 3.5"
# ]

# %% [markdown]
# ## Construct MODEL

# %%
model = Sequential([
    Conv2D(72,4,input_shape=(96,96,1),
           activation='relu',
           kernel_initializer='he_normal',
           kernel_regularizer=regularizers.l2(0.01)),
    AvgPool2D(pool_size=(2,2)),
    Conv2D(48,2,activation='relu',
           use_bias=False,
           kernel_initializer='he_normal',
           kernel_regularizer=regularizers.l2(0.01)),
    BatchNormalization(),
    Flatten(),
    Dropout(0.5),
    Dense(48,activation='relu', 
          use_bias = True,
          bias_initializer='he_normal',
          bias_regularizer=regularizers.l2(0.01),
          kernel_initializer='he_normal', 
          kernel_regularizer=regularizers.l2(0.01)),
    Dense(30, activation='relu',
          use_bias = True,
          bias_initializer='he_normal',
          bias_regularizer=regularizers.l2(0.01),
          kernel_initializer='he_normal',
          kernel_regularizer=regularizers.l2(0.01))
])

model.compile(optimizer=Adam(0.001),loss='mse',metrics=['mae'])

# %% [markdown]
# ## MODEL summary
#     KERAS provides convenient tools to check
#     what the model looks like. Refer to below;

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 93, 93, 72)        1224
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 46, 46, 72)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 48)        13824
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 45, 45, 48)        192
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 97200)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 97200)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 48)                4665648
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                1470
# =================================================================
# Total params: 4,682,358
# Trainable params: 4,682,262
# Non-trainable params: 96
# _________________________________________________________________

# %%
model.input, model.output
# Out:
# (<tf.Tensor 'conv2d_1_input:0' shape=(?, 96, 96, 1) dtype=float32>,
#  <tf.Tensor 'dense_2/Relu:0' shape=(?, 30) dtype=float32>)

# %% [markdown]
# ## TRAIN ze model
#
# In order to stabilize activation function ReLu,
#
# reduce Learning Rate per n epochs.
#
# https://keras.io/callbacks/#reducelronplateau
#
#     current learning rate is 0.01
#     if loss is not consistent,
#     it will be reduced by factor of 0.2,
#     at every 5 epoch,
#     until minimum learning rate 0.001 is reached

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                      patience=5, min_lr=0.0001)

# 100 epochs is most preferrable
# by making an instance of model.fit(),
# we can make analysis of the training process.
log = model.fit(x_train_norm, 
                y_train, 
                epochs = 100,
                batch_size = 10,
                validation_data=[x_val_norm, y_val],
                callbacks=[reduce_lr])
# Out:
# Train on 5600 samples, validate on 1400 samples
# Epoch 1/100
# 5600/5600 [==============================] - 96s 17ms/step - loss: 146.1605 - mean_absolute_error: 6.7681 - val_loss: 107.7639 - val_mean_absolute_error: 8.7901
# Epoch 2/100
# 5600/5600 [==============================] - 93s 17ms/step - loss: 21.2906 - mean_absolute_error: 2.7113 - val_loss: 20.0932 - val_mean_absolute_error: 2.6390
# Epoch 3/100
# 5600/5600 [==============================] - 93s 17ms/step - loss: 17.5017 - mean_absolute_error: 2.4213 - val_loss: 17.8750 - val_mean_absolute_error: 2.5011
# Epoch 4/100
# 5600/5600 [==============================] - 93s 17ms/step - loss: 14.5761 - mean_absolute_error: 2.1645 - val_loss: 13.5074 - val_mean_absolute_error: 2.0598
# Epoch 5/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 12.6546 - mean_absolute_error: 1.9929 - val_loss: 12.1997 - val_mean_absolute_error: 1.8995
# Epoch 6/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 11.5563 - mean_absolute_error: 1.8715 - val_loss: 16.4147 - val_mean_absolute_error: 2.6214
# Epoch 7/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 11.0045 - mean_absolute_error: 1.8198 - val_loss: 10.6153 - val_mean_absolute_error: 1.6925
# Epoch 8/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 10.7454 - mean_absolute_error: 1.7716 - val_loss: 11.1834 - val_mean_absolute_error: 1.7659
# Epoch 9/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 10.4999 - mean_absolute_error: 1.7391 - val_loss: 11.6200 - val_mean_absolute_error: 1.9104
# Epoch 10/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 10.0567 - mean_absolute_error: 1.6926 - val_loss: 10.4802 - val_mean_absolute_error: 1.6961
# Epoch 11/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 10.1650 - mean_absolute_error: 1.7127 - val_loss: 10.3361 - val_mean_absolute_error: 1.6530
# Epoch 12/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 9.5902 - mean_absolute_error: 1.6497 - val_loss: 9.7652 - val_mean_absolute_error: 1.5982
# Epoch 13/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 9.5013 - mean_absolute_error: 1.6271 - val_loss: 9.9744 - val_mean_absolute_error: 1.6330
# Epoch 14/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 9.5725 - mean_absolute_error: 1.6306 - val_loss: 9.2908 - val_mean_absolute_error: 1.5181
# Epoch 15/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 9.2702 - mean_absolute_error: 1.6123 - val_loss: 11.5090 - val_mean_absolute_error: 1.8645
# Epoch 16/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 9.5652 - mean_absolute_error: 1.6244 - val_loss: 9.4910 - val_mean_absolute_error: 1.5410
# Epoch 17/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 8.7838 - mean_absolute_error: 1.5505 - val_loss: 8.8713 - val_mean_absolute_error: 1.4741
# Epoch 18/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 8.5631 - mean_absolute_error: 1.5269 - val_loss: 9.4438 - val_mean_absolute_error: 1.6549
# Epoch 19/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 9.0216 - mean_absolute_error: 1.5929 - val_loss: 9.0925 - val_mean_absolute_error: 1.5701
# Epoch 20/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 8.4525 - mean_absolute_error: 1.5197 - val_loss: 8.6216 - val_mean_absolute_error: 1.4768
# Epoch 21/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 9.6333 - mean_absolute_error: 1.6226 - val_loss: 10.7398 - val_mean_absolute_error: 1.8041
# Epoch 22/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 9.4607 - mean_absolute_error: 1.5943 - val_loss: 8.3307 - val_mean_absolute_error: 1.4047
# Epoch 23/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 8.5583 - mean_absolute_error: 1.5379 - val_loss: 8.7155 - val_mean_absolute_error: 1.4844
# Epoch 24/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 8.5344 - mean_absolute_error: 1.5406 - val_loss: 8.7765 - val_mean_absolute_error: 1.5167
# Epoch 25/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 8.7591 - mean_absolute_error: 1.5947 - val_loss: 8.3034 - val_mean_absolute_error: 1.4399
# Epoch 26/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 8.3526 - mean_absolute_error: 1.5460 - val_loss: 9.0278 - val_mean_absolute_error: 1.5535
# Epoch 27/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 8.3358 - mean_absolute_error: 1.5437 - val_loss: 9.9343 - val_mean_absolute_error: 1.7463
# Epoch 28/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 8.1516 - mean_absolute_error: 1.5263 - val_loss: 8.5684 - val_mean_absolute_error: 1.5109
# Epoch 29/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 8.0172 - mean_absolute_error: 1.5092 - val_loss: 9.7425 - val_mean_absolute_error: 1.7379
# Epoch 30/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 8.1892 - mean_absolute_error: 1.5325 - val_loss: 8.7929 - val_mean_absolute_error: 1.5559
# Epoch 31/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 6.3963 - mean_absolute_error: 1.2460 - val_loss: 7.1657 - val_mean_absolute_error: 1.3725
# Epoch 32/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 5.7665 - mean_absolute_error: 1.1999 - val_loss: 6.5281 - val_mean_absolute_error: 1.2909
# Epoch 33/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 5.3942 - mean_absolute_error: 1.1815 - val_loss: 6.2904 - val_mean_absolute_error: 1.2851
# Epoch 34/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 5.1152 - mean_absolute_error: 1.1670 - val_loss: 6.2245 - val_mean_absolute_error: 1.3058
# Epoch 35/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 4.8654 - mean_absolute_error: 1.1438 - val_loss: 6.0298 - val_mean_absolute_error: 1.2962
# Epoch 36/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 4.7187 - mean_absolute_error: 1.1307 - val_loss: 5.9267 - val_mean_absolute_error: 1.2893
# Epoch 37/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 4.5875 - mean_absolute_error: 1.1198 - val_loss: 6.0104 - val_mean_absolute_error: 1.3186
# Epoch 38/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 4.5135 - mean_absolute_error: 1.1184 - val_loss: 5.6768 - val_mean_absolute_error: 1.2641
# Epoch 39/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 4.4038 - mean_absolute_error: 1.1094 - val_loss: 5.6309 - val_mean_absolute_error: 1.2582
# Epoch 40/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 4.2742 - mean_absolute_error: 1.0948 - val_loss: 5.6243 - val_mean_absolute_error: 1.2748
# Epoch 41/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 4.2011 - mean_absolute_error: 1.0944 - val_loss: 5.5645 - val_mean_absolute_error: 1.2628
# Epoch 42/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 4.0920 - mean_absolute_error: 1.0792 - val_loss: 5.6194 - val_mean_absolute_error: 1.2963
# Epoch 43/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 3.9795 - mean_absolute_error: 1.0626 - val_loss: 5.4920 - val_mean_absolute_error: 1.2619
# Epoch 44/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 4.0352 - mean_absolute_error: 1.0747 - val_loss: 5.5959 - val_mean_absolute_error: 1.3006
# Epoch 45/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 3.9876 - mean_absolute_error: 1.0701 - val_loss: 5.6307 - val_mean_absolute_error: 1.3096
# Epoch 46/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 3.9620 - mean_absolute_error: 1.0687 - val_loss: 5.4266 - val_mean_absolute_error: 1.2691
# Epoch 47/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 3.8753 - mean_absolute_error: 1.0623 - val_loss: 5.4470 - val_mean_absolute_error: 1.2729
# Epoch 48/100
# 5600/5600 [==============================] - 94s 17ms/step - loss: 3.8567 - mean_absolute_error: 1.0550 - val_loss: 5.3247 - val_mean_absolute_error: 1.2442
# Epoch 49/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.8267 - mean_absolute_error: 1.0593 - val_loss: 5.6324 - val_mean_absolute_error: 1.3432
# Epoch 50/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.7984 - mean_absolute_error: 1.0547 - val_loss: 5.3378 - val_mean_absolute_error: 1.2545
# Epoch 51/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.7953 - mean_absolute_error: 1.0578 - val_loss: 5.4308 - val_mean_absolute_error: 1.2906
# Epoch 52/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.8104 - mean_absolute_error: 1.0564 - val_loss: 5.6677 - val_mean_absolute_error: 1.3567
# Epoch 53/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.7491 - mean_absolute_error: 1.0449 - val_loss: 5.3186 - val_mean_absolute_error: 1.2698
# Epoch 54/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.7347 - mean_absolute_error: 1.0530 - val_loss: 5.4018 - val_mean_absolute_error: 1.2983
# Epoch 55/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.6611 - mean_absolute_error: 1.0395 - val_loss: 5.2973 - val_mean_absolute_error: 1.2610
# Epoch 56/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.6816 - mean_absolute_error: 1.0458 - val_loss: 5.6740 - val_mean_absolute_error: 1.3570
# Epoch 57/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.6881 - mean_absolute_error: 1.0521 - val_loss: 5.4381 - val_mean_absolute_error: 1.3082
# Epoch 58/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.7126 - mean_absolute_error: 1.0546 - val_loss: 5.3896 - val_mean_absolute_error: 1.2834
# Epoch 59/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.6095 - mean_absolute_error: 1.0379 - val_loss: 5.3945 - val_mean_absolute_error: 1.2918
# Epoch 60/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.6836 - mean_absolute_error: 1.0463 - val_loss: 5.4720 - val_mean_absolute_error: 1.3099
# Epoch 61/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.3674 - mean_absolute_error: 0.9814 - val_loss: 5.1700 - val_mean_absolute_error: 1.2427
# Epoch 62/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.2987 - mean_absolute_error: 0.9665 - val_loss: 5.1187 - val_mean_absolute_error: 1.2470
# Epoch 63/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.2556 - mean_absolute_error: 0.9633 - val_loss: 5.0804 - val_mean_absolute_error: 1.2374
# Epoch 64/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.1676 - mean_absolute_error: 0.9524 - val_loss: 5.1069 - val_mean_absolute_error: 1.2484
# Epoch 65/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.1416 - mean_absolute_error: 0.9533 - val_loss: 4.9998 - val_mean_absolute_error: 1.2323
# Epoch 66/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.1031 - mean_absolute_error: 0.9469 - val_loss: 5.1519 - val_mean_absolute_error: 1.2801
# Epoch 67/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.1155 - mean_absolute_error: 0.9508 - val_loss: 5.0413 - val_mean_absolute_error: 1.2591
# Epoch 68/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.0742 - mean_absolute_error: 0.9434 - val_loss: 5.0040 - val_mean_absolute_error: 1.2395
# Epoch 69/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.0521 - mean_absolute_error: 0.9411 - val_loss: 5.0261 - val_mean_absolute_error: 1.2528
# Epoch 70/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.0043 - mean_absolute_error: 0.9333 - val_loss: 4.9547 - val_mean_absolute_error: 1.2389
# Epoch 71/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.0085 - mean_absolute_error: 0.9386 - val_loss: 4.9742 - val_mean_absolute_error: 1.2471
# Epoch 72/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.9864 - mean_absolute_error: 0.9433 - val_loss: 4.9548 - val_mean_absolute_error: 1.2371
# Epoch 73/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 3.0298 - mean_absolute_error: 0.9462 - val_loss: 4.9364 - val_mean_absolute_error: 1.2462
# Epoch 74/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.9780 - mean_absolute_error: 0.9409 - val_loss: 5.0173 - val_mean_absolute_error: 1.2585
# Epoch 75/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.9299 - mean_absolute_error: 0.9331 - val_loss: 5.0533 - val_mean_absolute_error: 1.2691
# Epoch 76/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.9993 - mean_absolute_error: 0.9397 - val_loss: 4.9813 - val_mean_absolute_error: 1.2533
# Epoch 77/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.9532 - mean_absolute_error: 0.9374 - val_loss: 5.0754 - val_mean_absolute_error: 1.2872
# Epoch 78/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.9848 - mean_absolute_error: 0.9431 - val_loss: 4.9285 - val_mean_absolute_error: 1.2424
# Epoch 79/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.9440 - mean_absolute_error: 0.9344 - val_loss: 5.0032 - val_mean_absolute_error: 1.2725
# Epoch 80/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.8791 - mean_absolute_error: 0.9284 - val_loss: 4.9431 - val_mean_absolute_error: 1.2601
# Epoch 81/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.8958 - mean_absolute_error: 0.9279 - val_loss: 4.9950 - val_mean_absolute_error: 1.2797
# Epoch 82/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.9004 - mean_absolute_error: 0.9299 - val_loss: 4.8718 - val_mean_absolute_error: 1.2359
# Epoch 83/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.8713 - mean_absolute_error: 0.9287 - val_loss: 4.8986 - val_mean_absolute_error: 1.2400
# Epoch 84/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.8678 - mean_absolute_error: 0.9246 - val_loss: 5.0469 - val_mean_absolute_error: 1.2926
# Epoch 85/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.8756 - mean_absolute_error: 0.9305 - val_loss: 4.9533 - val_mean_absolute_error: 1.2635
# Epoch 86/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.8721 - mean_absolute_error: 0.9292 - val_loss: 4.9702 - val_mean_absolute_error: 1.2792
# Epoch 87/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.8287 - mean_absolute_error: 0.9299 - val_loss: 5.4120 - val_mean_absolute_error: 1.4155
# Epoch 88/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.9451 - mean_absolute_error: 0.9451 - val_loss: 4.9230 - val_mean_absolute_error: 1.2594
# Epoch 89/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.9102 - mean_absolute_error: 0.9376 - val_loss: 4.9424 - val_mean_absolute_error: 1.2787
# Epoch 90/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.8721 - mean_absolute_error: 0.9251 - val_loss: 4.8933 - val_mean_absolute_error: 1.2470
# Epoch 91/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.8260 - mean_absolute_error: 0.9262 - val_loss: 4.8472 - val_mean_absolute_error: 1.2392
# Epoch 92/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.8174 - mean_absolute_error: 0.9262 - val_loss: 4.8429 - val_mean_absolute_error: 1.2433
# Epoch 93/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.7775 - mean_absolute_error: 0.9199 - val_loss: 4.9406 - val_mean_absolute_error: 1.2713
# Epoch 94/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.8133 - mean_absolute_error: 0.9260 - val_loss: 4.8241 - val_mean_absolute_error: 1.2364
# Epoch 95/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.8111 - mean_absolute_error: 0.9210 - val_loss: 4.8095 - val_mean_absolute_error: 1.2369
# Epoch 96/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.7959 - mean_absolute_error: 0.9295 - val_loss: 4.8282 - val_mean_absolute_error: 1.2471
# Epoch 97/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.8102 - mean_absolute_error: 0.9281 - val_loss: 4.8844 - val_mean_absolute_error: 1.2499
# Epoch 98/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.8093 - mean_absolute_error: 0.9238 - val_loss: 4.8882 - val_mean_absolute_error: 1.2712
# Epoch 99/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.8396 - mean_absolute_error: 0.9341 - val_loss: 4.7828 - val_mean_absolute_error: 1.2213
# Epoch 100/100
# 5600/5600 [==============================] - 92s 16ms/step - loss: 2.8110 - mean_absolute_error: 0.9247 - val_loss: 4.7907 - val_mean_absolute_error: 1.2395

# %% [markdown]
# # Training Result

# %%
print(f'MAE final: {model.evaluate(x_val, y_val)[1]}')
print(f'MAE final: {model.evaluate(x_val_norm, y_val)[1]}')
# Out:
# 1400/1400 [==============================] - 5s 4ms/step
# MAE final: 19.500890535627093
# 1400/1400 [==============================] - 4s 3ms/step
# MAE final: 1.2394572946003506

# %%
# graphing the training loss and validation loss
# is useful to visually check for
# overfitting/overshotting,
# or any anomaly.
def show_results(log):
    fig, ax = plt.subplots(figsize=(8,4))
    ax.plot(log['loss'], label='train')
    ax.plot(log['val_loss'], label='validation')
    ax.set_xlabel('epoch'); ax.set_ylabel('loss')
    ax.legend()
    
log = log.history
show_results(log)

# %% [markdown]
# ## sample indexing w/ difference
# Mean Absolute Value:
#
# https://www.geogebra.org/m/UaMEvgyH

# %%
def show_pred(x, y_real, y_pred):
    fig, axes = plt.subplots(1, 2, figsize=(5,5))
    for ax in axes:
        ax.imshow(x[0, ..., 0], 'gray')
        ax.axis('off')
        
    points_real = np.vstack(np.split(y_real[0], 15)).T
    points_pred = np.vstack(np.split(y_pred[0], 15)).T
    
    axes[0].plot(points_pred[0], points_pred[1], 'o', color='red')
    axes[0].set_title('Predictions', size=16)
    
    axes[1].plot(points_real[0], points_real[1], 'o', color='green')
    axes[1].plot(points_pred[0], points_pred[1], 'o', color='red', alpha=0.5)
    axes[1].set_title('Real', size=16)

# %%
# calculate the difference,
# between predicted value and real value
predicted_val=model.predict(x_val_norm)
residual_val=np.abs(predicted_val - y_val)
# MAD ==> Mean Absolute Value
# 30 ==> number of labels(x+y)
# not sure why y_val is treated as mean?
mad_val=np.sum(residual_val, axis=1)/30

# indices == index
# sort by the difference
# between predicted value and real value
indices=mad_val.argsort()
indices.shape
# Out:
# (1400,)

# %%
# Random Sample comparison
for _ in range(5):
    index = np.random.choice(x_val_norm.shape[0])
    sample_x = x_val_norm[index, None]
    sample_y = y_val[index, None]
    pred = model.predict(sample_x)
    show_pred(sample_x, sample_y, pred)

# %%
# Most Alike
for i in range(5):
    sample_x = x_val_norm[indices[i], None]
    sample_y = y_val[indices[i], None]
    pred = model.predict(sample_x)
    show_pred(sample_x, sample_y, pred)

# %%
# Least Alike
# it's obvious that side-face pics are the worst
for i in [-1,-2,-3,-4,-5]:
    sample_x = x_val_norm[indices[i], None]
    sample_y = y_val[indices[i], None]
    pred = model.predict(sample_x)
    show_pred(sample_x, sample_y, pred)

# %% [markdown]
# # Create Submission

# %%
Test_Dir = '../data/face/test.csv'
lookid_dir = '../data/face/IdLookupTable.csv'
test_data = pd.read_csv(Test_Dir)
lookid_data = pd.read_csv(lookid_dir)

# %%
# get image section of test data
def format_img(x):
    return np.asarray([int(e) for e in x.split(' ')], dtype=np.uint8).reshape(96,96)

with Parallel(n_jobs=10, verbose=1, prefer='threads') as ex:
    X_test = ex(delayed(format_img)(e) for e in test_data.Image)
    
X_test = np.stack(X_test)[..., None]
X_test.shape
# Out:
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 180 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=10)]: Done 430 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=10)]: Done 780 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=10)]: Done 1230 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=10)]: Done 1783 out of 1783 | elapsed:    5.0s finished
# (1783, 96, 96, 1)

# %%
# standardize test dataset
X_test_norm=X_test[:,:,:,:]
X_test_norm=X_test_norm.reshape([1783,96*96,1])
# mu=x_train_norm.mean()
# sigma=x_train_norm.std()
X_test_norm=(X_test_norm - mu)/sigma
X_test_norm=X_test_norm.reshape([1783,96,96,1])

# %%
# make prediction
pred = model.predict(X_test_norm)

# %%
# this submission requires looking up
# IdLookUpTable provided by Kaggle
# every 30 rows (rowId) are considered one image
lookid_list = list(lookid_data['FeatureName'])
imageID = list(lookid_data['ImageId']-1)
pre_list = list(pred)
rowid=list(lookid_data['RowId'])

# index of each feature is extracted
feature = []
for f in list(lookid_data['FeatureName']):
    feature.append(lookid_list.index(f))

# as per imageID and feature index,
# values from predction is extracted,
# and appended to a list 'preded'
# pred[0][0] ==> ~66 ==> 1st image, 1st feature(left eye center x)
preded = []
for x,y in zip(imageID,feature):
    preded.append(pre_list[x][y])

# rowid converted to dataframe
rowid = pd.Series(rowid, name = 'RowId')
# features converted to dataframe
loc = pd.Series(preded, name = 'Location')
# rowid, and loc dataframes are concated
submission = pd.concat([rowid,loc],axis = 1)

# %%
# save submission file
submission.to_csv('../data/predictions/face_10_7000_samples.csv',index = False)

# %%
submission.head()
# Out:
#    RowId   Location
# 0      1  65.114098
# 1      2  36.846626
# 2      3  28.347878
# 3      4  36.695896
# 4      5  59.584175

# %% [markdown]
# # ASSESSMENT

# %% [markdown]
# ![face_9_result](https://user-images.githubusercontent.com/44990492/56116789-a985c380-5fa1-11e9-939f-f2756dc09a7b.png)
#
#     note: 3 dense network did 4.1
#     adding CNN + Normalization + CALLBACK improved it to 3.8
#     adding BIAS improved it to 3.1
#
#     face_7 (w/o bias):
#         loss: 6.3249 - mean_absolute_error: 1.7404
#         val_loss: 6.9588 - val_mean_absolute_error: 1.8378
#
#     face_8 (w bias):
#         loss: 1.8949 - mean_absolute_error: 0.6170
#         val_loss: 3.7994 - val_mean_absolute_error: 1.0542

# %% [markdown]
# ![face_7_loss_graph](https://user-images.githubusercontent.com/44990492/56116942-fd90a800-5fa1-11e9-88ea-3c4fda0646dc.png)
#
# ![face_8_loss_graph](https://user-images.githubusercontent.com/44990492/56116945-fd90a800-5fa1-11e9-8dda-59f954bf73dc.png)
#
# ![face_9_loss_graph](https://user-images.githubusercontent.com/44990492/56116946-fd90a800-5fa1-11e9-9cd9-157236bad03c.png)
#
#     It seems adding bias does stablize the loss (activation function).
#     Model with bias have comparably lower loss - although the cause
#     could be the random weight value;
#     graph does show that model without bias started above 400.
