# %% [markdown]
# <h1>Facial Keypoints Detection<span class="tocSkip"></span></h1>
#
#     a simple Convolutional Deep Neural Network model
#     for detecting facial keypoints,
#     such as location of location of eye brows, eyes, nose, and mouth.
#
# Link: https://www.kaggle.com/c/facial-keypoints-detection

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Resource-Monitor" data-toc-modified-id="Resource-Monitor-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Resource Monitor</a></span></li><li><span><a href="#Data" data-toc-modified-id="Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data</a></span><ul class="toc-item"><li><span><a href="#import" data-toc-modified-id="import-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>import</a></span></li><li><span><a href="#Data-Processing" data-toc-modified-id="Data-Processing-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Data Processing</a></span></li><li><span><a href="#Training-&amp;-Validaiton-Dataset-SPLIT" data-toc-modified-id="Training-&amp;-Validaiton-Dataset-SPLIT-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Training &amp; Validaiton Dataset SPLIT</a></span></li><li><span><a href="#Training-Dataset-Standardization" data-toc-modified-id="Training-Dataset-Standardization-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Training Dataset Standardization</a></span><ul class="toc-item"><li><span><a href="#standardization-Result" data-toc-modified-id="standardization-Result-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>standardization Result</a></span></li></ul></li></ul></li><li><span><a href="#Model" data-toc-modified-id="Model-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Model</a></span><ul class="toc-item"><li><span><a href="#KERAS-import" data-toc-modified-id="KERAS-import-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>KERAS import</a></span></li><li><span><a href="#GPU-availability-check" data-toc-modified-id="GPU-availability-check-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>GPU availability check</a></span></li><li><span><a href="#Construct-MODEL" data-toc-modified-id="Construct-MODEL-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Construct MODEL</a></span></li><li><span><a href="#MODEL-summary" data-toc-modified-id="MODEL-summary-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>MODEL summary</a></span></li><li><span><a href="#TRAIN-ze-model" data-toc-modified-id="TRAIN-ze-model-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>TRAIN ze model</a></span></li></ul></li><li><span><a href="#Training-Result" data-toc-modified-id="Training-Result-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Training Result</a></span><ul class="toc-item"><li><span><a href="#sample-indexing-w/-difference" data-toc-modified-id="sample-indexing-w/-difference-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>sample indexing w/ difference</a></span></li></ul></li><li><span><a href="#Create-Submission" data-toc-modified-id="Create-Submission-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Create Submission</a></span></li><li><span><a href="#ASSESSMENT" data-toc-modified-id="ASSESSMENT-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>ASSESSMENT</a></span></li></ul></div>

# %% [markdown]
# # Resource Monitor
#
# CPUMon
#
# download: https://www.downloadcrew.com/article/35114-cpumon
#
#     very simple lightweight graphical CPU monitor.
#     Good for keeping CPU and memory in check,
#     especially if training dataset is ridiculously big.
#     Standalone, no installation.
#
# GPU-Z
#
# download: https://www.techpowerup.com/download/techpowerup-gpu-z/
#
#     also simple and lightweight, monitors GPU sensors.
#     Good for keeping track of GPU usuage, especially memory,
#     considering GPU memory is rather small.
#     Standalone, no installation.
#     *** Tensorflow tends to allocate all the GPU memory,
#     unless otherwise directed, and there's no other way to
#     free the GPU memory until the python kernel is killed ***

# %%
import os

os.startfile(r'C:\STUDY\resource_monitor\CPUMon.exe')
os.startfile(r'C:\STUDY\resource_monitor\GPU-Z.exe')

# %% [markdown]
# # Data

# %% [markdown]
# ## import

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Data Processing

# %%
df = pd.read_csv('../data/face/training.csv')
# it's a shame, but for now, drop all null
df.dropna(inplace=True)
df.shape
# Out:
# (2140, 31)

# %%
# using parallel processing
# 10 threads
# to separate "image" section into var x
from joblib import Parallel, delayed

def format_img(x):
    return np.asarray([int(e) for e in x.split(' ')], dtype=np.uint8).reshape(96,96)

# ref: https://joblib.readthedocs.io/en/latest/parallel.html
with Parallel(n_jobs=10, verbose=1, prefer='threads') as ex:
    x = ex(delayed(format_img)(e) for e in df.Image)
    
x = np.stack(x)[..., None]
x.shape
# Out:
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 180 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=10)]: Done 430 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=10)]: Done 780 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=10)]: Done 1230 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=10)]: Done 1780 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=10)]: Done 2140 out of 2140 | elapsed:    6.0s finished
# (2140, 96, 96, 1)

# %%
y = df.iloc[:, :-1].values
y.shape
# Out:
# (2140, 30)

# %%
# uses matplotlib to graph picture based on "image" data
def show(x, y=None):
    plt.imshow(x[..., 0], "gray")
    # plots y (label) data on top
    if y is not None:
        points = np.vstack(np.split(y, 15)).T
        plt.plot(points[0], points[1], 'o', color='yellow')
        
    plt.axis('off')

# %%
sample_idx = np.random.choice(len(x))    
show(x[sample_idx], y[sample_idx])

# %% [markdown]
# ## Training & Validaiton Dataset SPLIT

# %%
# separate training dataset, validation dataset
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# x data train set, x data validation set
x_train.shape, x_val.shape
# Out:
# ((1712, 96, 96, 1), (428, 96, 96, 1))

# %%
# y data train set, y data validation set
y_train.shape, y_val.shape
# Out:
# ((1712, 30), (428, 30))

# %% [markdown]
# ## Training Dataset Standardization
#
# refer to: https://maristie.com/blog/differences-between-normalization-standardization-and-regularization/

# %%
# x datasets reshaping for standardization
x_train_norm=x_train[:,:,:,:]
x_val_norm=x_val[:,:,:,:]
x_train_norm=x_train_norm.reshape([1712,96*96,1])
x_val_norm=x_val_norm.reshape([428,96*96,1])

# %%
# prepare for standardization
mu=x_train_norm.mean()
sigma=x_train_norm.std()
mu, sigma
# Out:
# (121.83461982513143, 59.23303696478942)

# %%
# standardize
x_train_norm=(x_train_norm - mu)/sigma
x_val_norm=(x_val_norm - mu)/sigma

# %%
# x training dataset shape, mean, std
x_train_norm.shape, x_train_norm.mean(), x_train_norm.std()
# Out:
# ((1712, 9216, 1), -9.338324506192905e-18, 0.9999999999999999)

# %%
# x validation dataset shape, mean, std
x_val_norm.shape, x_val_norm.mean(), x_val_norm.std()
# Out:
# ((428, 9216, 1), -0.06512222683585148, 0.9844637045228576)

# %%
# reshaping x datasets
x_train_norm=x_train_norm.reshape([1712,96,96,1])
x_val_norm=x_val_norm.reshape([428,96,96,1])

x_train_norm.shape, x_val_norm.shape
# Out:
# ((1712, 96, 96, 1), (428, 96, 96, 1))

# %% [markdown]
# ### standardization Result

# %%
print("{} is normalized to {}".format(x_train[0][0][0][0], x_train_norm[0][0][0][0]))
print("{} is normalized to {}".format(x_train[0][0][90][0], x_train_norm[0][0][90][0]))
# Out:
# 125 is normalized to 0.053439437467138605
# 91 is normalized to -0.5205645600015546

# %%
# checking if standardization worked properly
# show img of standardized x_train dataset
sample_idx = np.random.choice(len(x_train_norm))
show(x_train_norm[sample_idx], y_train[sample_idx])

# %%
# there shouldn't be any difference
# show img of raw x_train dataset
show(x_train[sample_idx], y_train[sample_idx])

# %% [markdown]
# # Model
#
# BATCH NORMALIZATION:
#
# https://www.dlology.com/blog/one-simple-trick-to-train-keras-model-faster-with-batch-normalization/
#
#
# Conv2d:
#
# https://www.programcreek.com/python/example/89658/keras.layers.Conv2D

# %% [markdown]
# ## KERAS import

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, AvgPool2D, BatchNormalization, Dropout
from keras.optimizers import Adam
from keras import regularizers
from keras.callbacks import ReduceLROnPlateau
from keras.models import load_model
from keras.callbacks import CSVLogger
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## GPU availability check

# %%
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
# Out:
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 864822375671324341
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 561803264
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3825372713763913196
# physical_device_desc: "device: 0, name: GeForce GT 720, pci bus id: 0000:01:00.0, compute capability: 3.5"
# ]

# %% [markdown]
# ## Construct MODEL

# %%
model = Sequential([
    Conv2D(72,4,input_shape=(96,96,1),
           activation='relu',
           kernel_initializer='he_normal',
           kernel_regularizer=regularizers.l2(0.01)),
    AvgPool2D(pool_size=(2,2)),
    Conv2D(48,2,activation='relu',
           use_bias=False,
           kernel_initializer='he_normal',
           kernel_regularizer=regularizers.l2(0.01)),
    BatchNormalization(),
    Flatten(),
    Dropout(0.5),
    Dense(48,activation='relu', 
          use_bias = True,
          bias_initializer='he_normal',
          bias_regularizer=regularizers.l2(0.01),
          kernel_initializer='he_normal', 
          kernel_regularizer=regularizers.l2(0.01)),
    Dense(30, activation='relu',
          use_bias = True,
          bias_initializer='he_normal',
          bias_regularizer=regularizers.l2(0.01),
          kernel_initializer='he_normal',
          kernel_regularizer=regularizers.l2(0.01))
])

model.compile(optimizer=Adam(0.001),loss='mse',metrics=['mae'])

# %% [markdown]
# ## MODEL summary
#     KERAS provides convenient tools to check
#     what the model looks like. Refer to below;

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 93, 93, 72)        1224
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 46, 46, 72)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 48)        13824
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 45, 45, 48)        192
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 97200)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 97200)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 48)                4665648
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                1470
# =================================================================
# Total params: 4,682,358
# Trainable params: 4,682,262
# Non-trainable params: 96
# _________________________________________________________________

# %%
model.input, model.output
# Out:
# (<tf.Tensor 'conv2d_1_input:0' shape=(?, 96, 96, 1) dtype=float32>,
#  <tf.Tensor 'dense_2/Relu:0' shape=(?, 30) dtype=float32>)

# %% [markdown]
# ## TRAIN ze model
#
# In order to stabilize activation function ReLu,
#
# reduce Learning Rate per n epochs.
#
# https://keras.io/callbacks/#reducelronplateau
#
#     current learning rate is 0.01
#     if loss is not consistent,
#     it will be reduced by factor of 0.2,
#     at every 5 epoch,
#     until minimum learning rate 0.001 is reached

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                      patience=5, min_lr=0.0001)

# 100 epochs is most preferrable
# by making an instance of model.fit(),
# we can make analysis of the training process.
log = model.fit(x_train_norm, 
                y_train, 
                epochs = 100,
                batch_size = 10,
                validation_data=[x_val_norm, y_val],
                callbacks=[reduce_lr])
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/100
# 1712/1712 [==============================] - 31s 18ms/step - loss: 420.4969 - mean_absolute_error: 14.0585 - val_loss: 253.4816 - val_mean_absolute_error: 12.4512
# Epoch 2/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 94.6464 - mean_absolute_error: 5.8609 - val_loss: 210.5274 - val_mean_absolute_error: 11.7668
# Epoch 3/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 75.8220 - mean_absolute_error: 4.5617 - val_loss: 119.5326 - val_mean_absolute_error: 7.9724
# Epoch 4/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 69.8097 - mean_absolute_error: 4.0700 - val_loss: 72.7896 - val_mean_absolute_error: 4.4403
# Epoch 5/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 67.0345 - mean_absolute_error: 3.8008 - val_loss: 74.3394 - val_mean_absolute_error: 4.6258
# Epoch 6/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 65.1966 - mean_absolute_error: 3.6294 - val_loss: 72.3107 - val_mean_absolute_error: 4.5016
# Epoch 7/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 64.6746 - mean_absolute_error: 3.6032 - val_loss: 63.7329 - val_mean_absolute_error: 3.4330
# Epoch 8/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 63.9131 - mean_absolute_error: 3.5439 - val_loss: 63.3114 - val_mean_absolute_error: 3.3893
# Epoch 9/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 62.9001 - mean_absolute_error: 3.4554 - val_loss: 63.2742 - val_mean_absolute_error: 3.4330
# Epoch 10/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 62.2806 - mean_absolute_error: 3.4093 - val_loss: 62.0381 - val_mean_absolute_error: 3.2934
# Epoch 11/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 62.0046 - mean_absolute_error: 3.3954 - val_loss: 62.1992 - val_mean_absolute_error: 3.3620
# Epoch 12/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 61.1885 - mean_absolute_error: 3.3144 - val_loss: 61.0935 - val_mean_absolute_error: 3.2390
# Epoch 13/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 60.2422 - mean_absolute_error: 3.2076 - val_loss: 60.3927 - val_mean_absolute_error: 3.1638
# Epoch 14/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 59.6051 - mean_absolute_error: 3.1497 - val_loss: 60.2086 - val_mean_absolute_error: 3.1288
# Epoch 15/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 59.3912 - mean_absolute_error: 3.1476 - val_loss: 59.8773 - val_mean_absolute_error: 3.1295
# Epoch 16/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 58.5993 - mean_absolute_error: 3.0519 - val_loss: 59.3609 - val_mean_absolute_error: 3.0993
# Epoch 17/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 57.8872 - mean_absolute_error: 2.9582 - val_loss: 58.4297 - val_mean_absolute_error: 2.9465
# Epoch 18/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 57.3401 - mean_absolute_error: 2.8798 - val_loss: 58.2247 - val_mean_absolute_error: 2.9309
# Epoch 19/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 56.9215 - mean_absolute_error: 2.8438 - val_loss: 58.3115 - val_mean_absolute_error: 2.9916
# Epoch 20/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 56.8073 - mean_absolute_error: 2.8468 - val_loss: 58.9762 - val_mean_absolute_error: 3.1634
# Epoch 21/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 56.4656 - mean_absolute_error: 2.7910 - val_loss: 58.6567 - val_mean_absolute_error: 3.0679
# Epoch 22/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 55.9590 - mean_absolute_error: 2.7035 - val_loss: 58.0471 - val_mean_absolute_error: 3.0292
# Epoch 23/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 55.5738 - mean_absolute_error: 2.6580 - val_loss: 56.8212 - val_mean_absolute_error: 2.7597
# Epoch 24/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 55.4343 - mean_absolute_error: 2.6503 - val_loss: 58.1799 - val_mean_absolute_error: 3.0776
# Epoch 25/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 55.3708 - mean_absolute_error: 2.6556 - val_loss: 57.4388 - val_mean_absolute_error: 2.9340
# Epoch 26/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 55.1104 - mean_absolute_error: 2.6137 - val_loss: 56.0760 - val_mean_absolute_error: 2.6784
# Epoch 27/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 55.2260 - mean_absolute_error: 2.6472 - val_loss: 58.2710 - val_mean_absolute_error: 3.1709
# Epoch 28/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 55.0919 - mean_absolute_error: 2.6366 - val_loss: 56.8549 - val_mean_absolute_error: 2.8867
# Epoch 29/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.9497 - mean_absolute_error: 2.6080 - val_loss: 56.1668 - val_mean_absolute_error: 2.7142
# Epoch 30/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.8454 - mean_absolute_error: 2.5953 - val_loss: 55.8132 - val_mean_absolute_error: 2.6592
# Epoch 31/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.6856 - mean_absolute_error: 2.5764 - val_loss: 56.0344 - val_mean_absolute_error: 2.7321
# Epoch 32/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.4701 - mean_absolute_error: 2.5356 - val_loss: 58.0545 - val_mean_absolute_error: 3.1758
# Epoch 33/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.5408 - mean_absolute_error: 2.5592 - val_loss: 56.0215 - val_mean_absolute_error: 2.7548
# Epoch 34/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.4508 - mean_absolute_error: 2.5524 - val_loss: 55.6587 - val_mean_absolute_error: 2.6658
# Epoch 35/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.4627 - mean_absolute_error: 2.5528 - val_loss: 56.0422 - val_mean_absolute_error: 2.7473
# Epoch 36/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.4424 - mean_absolute_error: 2.5503 - val_loss: 55.5656 - val_mean_absolute_error: 2.6538
# Epoch 37/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.3531 - mean_absolute_error: 2.5521 - val_loss: 55.2839 - val_mean_absolute_error: 2.6129
# Epoch 38/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.3429 - mean_absolute_error: 2.5392 - val_loss: 55.6622 - val_mean_absolute_error: 2.6882
# Epoch 39/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.2173 - mean_absolute_error: 2.5236 - val_loss: 55.9714 - val_mean_absolute_error: 2.7747
# Epoch 40/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.3436 - mean_absolute_error: 2.5445 - val_loss: 57.5643 - val_mean_absolute_error: 3.1342
# Epoch 41/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.2824 - mean_absolute_error: 2.5322 - val_loss: 55.1757 - val_mean_absolute_error: 2.5921
# Epoch 42/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.0939 - mean_absolute_error: 2.5117 - val_loss: 56.7713 - val_mean_absolute_error: 2.9629
# Epoch 43/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.2387 - mean_absolute_error: 2.5335 - val_loss: 55.9363 - val_mean_absolute_error: 2.7799
# Epoch 44/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.3286 - mean_absolute_error: 2.5590 - val_loss: 55.2622 - val_mean_absolute_error: 2.6390
# Epoch 45/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.2351 - mean_absolute_error: 2.5285 - val_loss: 55.3954 - val_mean_absolute_error: 2.6427
# Epoch 46/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 54.2328 - mean_absolute_error: 2.5354 - val_loss: 55.6485 - val_mean_absolute_error: 2.7222
# Epoch 47/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 53.3689 - mean_absolute_error: 2.3314 - val_loss: 54.4973 - val_mean_absolute_error: 2.4592
# Epoch 48/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 53.0177 - mean_absolute_error: 2.2784 - val_loss: 54.2072 - val_mean_absolute_error: 2.4286
# Epoch 49/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 52.7246 - mean_absolute_error: 2.2358 - val_loss: 54.1226 - val_mean_absolute_error: 2.4458
# Epoch 50/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 52.5705 - mean_absolute_error: 2.2320 - val_loss: 53.9342 - val_mean_absolute_error: 2.4213
# Epoch 51/100
# 1712/1712 [==============================] - 28s 17ms/step - loss: 52.3900 - mean_absolute_error: 2.2061 - val_loss: 53.8683 - val_mean_absolute_error: 2.4259
# Epoch 52/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 52.2686 - mean_absolute_error: 2.1918 - val_loss: 53.7294 - val_mean_absolute_error: 2.4184
# Epoch 53/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 52.1108 - mean_absolute_error: 2.1664 - val_loss: 54.0228 - val_mean_absolute_error: 2.5252
# Epoch 54/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 52.0321 - mean_absolute_error: 2.1665 - val_loss: 53.5394 - val_mean_absolute_error: 2.4114
# Epoch 55/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.9546 - mean_absolute_error: 2.1626 - val_loss: 53.6613 - val_mean_absolute_error: 2.4616
# Epoch 56/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.8234 - mean_absolute_error: 2.1400 - val_loss: 53.4140 - val_mean_absolute_error: 2.3905
# Epoch 57/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.7581 - mean_absolute_error: 2.1403 - val_loss: 53.3575 - val_mean_absolute_error: 2.3918
# Epoch 58/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.6612 - mean_absolute_error: 2.1238 - val_loss: 53.3075 - val_mean_absolute_error: 2.4106
# Epoch 59/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.6089 - mean_absolute_error: 2.1275 - val_loss: 53.2023 - val_mean_absolute_error: 2.3737
# Epoch 60/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.6058 - mean_absolute_error: 2.1410 - val_loss: 53.2550 - val_mean_absolute_error: 2.4099
# Epoch 61/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.4849 - mean_absolute_error: 2.1136 - val_loss: 53.1077 - val_mean_absolute_error: 2.3879
# Epoch 62/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.4369 - mean_absolute_error: 2.1110 - val_loss: 53.0755 - val_mean_absolute_error: 2.3738
# Epoch 63/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.3914 - mean_absolute_error: 2.1048 - val_loss: 53.2122 - val_mean_absolute_error: 2.4182
# Epoch 64/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.3642 - mean_absolute_error: 2.1049 - val_loss: 53.0621 - val_mean_absolute_error: 2.3930
# Epoch 65/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.3271 - mean_absolute_error: 2.1080 - val_loss: 52.9444 - val_mean_absolute_error: 2.3626
# Epoch 66/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.3217 - mean_absolute_error: 2.1053 - val_loss: 52.8972 - val_mean_absolute_error: 2.3535
# Epoch 67/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.2200 - mean_absolute_error: 2.0834 - val_loss: 52.9315 - val_mean_absolute_error: 2.3704
# Epoch 68/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.2085 - mean_absolute_error: 2.0855 - val_loss: 53.0302 - val_mean_absolute_error: 2.4321
# Epoch 69/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.1769 - mean_absolute_error: 2.0847 - val_loss: 53.0243 - val_mean_absolute_error: 2.4133
# Epoch 70/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.1632 - mean_absolute_error: 2.0832 - val_loss: 52.8927 - val_mean_absolute_error: 2.3847
# Epoch 71/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.0899 - mean_absolute_error: 2.0724 - val_loss: 52.8786 - val_mean_absolute_error: 2.3843
# Epoch 72/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.0881 - mean_absolute_error: 2.0784 - val_loss: 52.8937 - val_mean_absolute_error: 2.4065
# Epoch 73/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.0337 - mean_absolute_error: 2.0639 - val_loss: 52.7710 - val_mean_absolute_error: 2.3670
# Epoch 74/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 51.0164 - mean_absolute_error: 2.0633 - val_loss: 53.2849 - val_mean_absolute_error: 2.4961
# Epoch 75/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.9730 - mean_absolute_error: 2.0505 - val_loss: 52.6311 - val_mean_absolute_error: 2.3354
# Epoch 76/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.9538 - mean_absolute_error: 2.0546 - val_loss: 52.8410 - val_mean_absolute_error: 2.4208
# Epoch 77/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.9467 - mean_absolute_error: 2.0597 - val_loss: 52.6338 - val_mean_absolute_error: 2.3498
# Epoch 78/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.9247 - mean_absolute_error: 2.0517 - val_loss: 52.6657 - val_mean_absolute_error: 2.3628
# Epoch 79/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.9438 - mean_absolute_error: 2.0683 - val_loss: 52.7512 - val_mean_absolute_error: 2.3837
# Epoch 80/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.9251 - mean_absolute_error: 2.0576 - val_loss: 52.5904 - val_mean_absolute_error: 2.3487
# Epoch 81/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.8701 - mean_absolute_error: 2.0451 - val_loss: 52.7658 - val_mean_absolute_error: 2.3948
# Epoch 82/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.8140 - mean_absolute_error: 2.0309 - val_loss: 52.6849 - val_mean_absolute_error: 2.3702
# Epoch 83/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.8897 - mean_absolute_error: 2.0622 - val_loss: 52.6646 - val_mean_absolute_error: 2.3621
# Epoch 84/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.7731 - mean_absolute_error: 2.0278 - val_loss: 52.7148 - val_mean_absolute_error: 2.4161
# Epoch 85/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.7896 - mean_absolute_error: 2.0354 - val_loss: 52.4957 - val_mean_absolute_error: 2.3292
# Epoch 86/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.7461 - mean_absolute_error: 2.0228 - val_loss: 52.6109 - val_mean_absolute_error: 2.3662
# Epoch 87/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.7706 - mean_absolute_error: 2.0318 - val_loss: 52.4477 - val_mean_absolute_error: 2.3249
# Epoch 88/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.7858 - mean_absolute_error: 2.0388 - val_loss: 52.4466 - val_mean_absolute_error: 2.3146
# Epoch 89/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.8087 - mean_absolute_error: 2.0519 - val_loss: 52.6003 - val_mean_absolute_error: 2.3738
# Epoch 90/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.7660 - mean_absolute_error: 2.0414 - val_loss: 52.7150 - val_mean_absolute_error: 2.4003
# Epoch 91/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.7255 - mean_absolute_error: 2.0289 - val_loss: 52.7068 - val_mean_absolute_error: 2.4158
# Epoch 92/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.7566 - mean_absolute_error: 2.0452 - val_loss: 52.5482 - val_mean_absolute_error: 2.3508
# Epoch 93/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.7231 - mean_absolute_error: 2.0362 - val_loss: 52.5630 - val_mean_absolute_error: 2.3788
# Epoch 94/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.5714 - mean_absolute_error: 1.9805 - val_loss: 52.4090 - val_mean_absolute_error: 2.3174
# Epoch 95/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 50.4999 - mean_absolute_error: 1.9603 - val_loss: 52.2779 - val_mean_absolute_error: 2.2929
# Epoch 96/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 50.4606 - mean_absolute_error: 1.9511 - val_loss: 52.3642 - val_mean_absolute_error: 2.3153
# Epoch 97/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 28.3968 - mean_absolute_error: 1.4417 - val_loss: 4.3654 - val_mean_absolute_error: 1.0866
# Epoch 98/100
# 1712/1712 [==============================] - 28s 16ms/step - loss: 2.5433 - mean_absolute_error: 0.7403 - val_loss: 4.3335 - val_mean_absolute_error: 1.1404
# Epoch 99/100
# 1712/1712 [==============================] - 28s 17ms/step - loss: 2.2931 - mean_absolute_error: 0.7150 - val_loss: 3.9192 - val_mean_absolute_error: 1.0629
# Epoch 100/100
# 1712/1712 [==============================] - 29s 17ms/step - loss: 2.2057 - mean_absolute_error: 0.7170 - val_loss: 3.9442 - val_mean_absolute_error: 1.1033

# %% [markdown]
# # Training Result

# %%
print(f'MAE final: {model.evaluate(x_val, y_val)[1]}')
print(f'MAE final: {model.evaluate(x_val_norm, y_val)[1]}')
# Out:
# 428/428 [==============================] - 2s 4ms/step
# MAE final: 29.809575998894523
# 428/428 [==============================] - 1s 3ms/step
# MAE final: 1.103289385265279

# %%
# graphing the training loss and validation loss
# is useful to visually check for
# overfitting/overshotting,
# or any anomaly.
def show_results(log):
    fig, ax = plt.subplots(figsize=(8,4))
    ax.plot(log['loss'], label='train')
    ax.plot(log['val_loss'], label='validation')
    ax.set_xlabel('epoch'); ax.set_ylabel('loss')
    ax.legend()
    
log = log.history
show_results(log)

# %% [markdown]
# ## sample indexing w/ difference
# Mean Absolute Value:
#
# https://www.geogebra.org/m/UaMEvgyH

# %%
def show_pred(x, y_real, y_pred):
    fig, axes = plt.subplots(1, 2, figsize=(5,5))
    for ax in axes:
        ax.imshow(x[0, ..., 0], 'gray')
        ax.axis('off')
        
    points_real = np.vstack(np.split(y_real[0], 15)).T
    points_pred = np.vstack(np.split(y_pred[0], 15)).T
    
    axes[0].plot(points_pred[0], points_pred[1], 'o', color='red')
    axes[0].set_title('Predictions', size=16)
    
    axes[1].plot(points_real[0], points_real[1], 'o', color='green')
    axes[1].plot(points_pred[0], points_pred[1], 'o', color='red', alpha=0.5)
    axes[1].set_title('Real', size=16)

# %%
# calculate the difference,
# between predicted value and real value
predicted_val=model.predict(x_val_norm)
residual_val=np.abs(predicted_val - y_val)
# MAD ==> Mean Absolute Value
# 30 ==> number of labels(x+y)
# not sure why y_val is treated as mean?
mad_val=np.sum(residual_val, axis=1)/30

# indices == index
# sort by the difference
# between predicted value and real value
indices=mad_val.argsort()
indices.shape
# Out:
# (428,)

# %%
# Random Sample comparison
for _ in range(5):
    index = np.random.choice(x_val_norm.shape[0])
    sample_x = x_val_norm[index, None]
    sample_y = y_val[index, None]
    pred = model.predict(sample_x)
    show_pred(sample_x, sample_y, pred)

# %%
# Most Alike
for i in range(5):
    sample_x = x_val_norm[indices[i], None]
    sample_y = y_val[indices[i], None]
    pred = model.predict(sample_x)
    show_pred(sample_x, sample_y, pred)

# %%
# Least Alike
# it's obvious that side-face pics are the worst
for i in [-1,-2,-3,-4,-5]:
    sample_x = x_val_norm[indices[i], None]
    sample_y = y_val[indices[i], None]
    pred = model.predict(sample_x)
    show_pred(sample_x, sample_y, pred)

# %% [markdown]
# # Create Submission

# %%
Test_Dir = '../data/face/test.csv'
lookid_dir = '../data/face/IdLookupTable.csv'
test_data = pd.read_csv(Test_Dir)
lookid_data = pd.read_csv(lookid_dir)

# %%
# get image section of test data
def format_img(x):
    return np.asarray([int(e) for e in x.split(' ')], dtype=np.uint8).reshape(96,96)

with Parallel(n_jobs=10, verbose=1, prefer='threads') as ex:
    X_test = ex(delayed(format_img)(e) for e in test_data.Image)
    
X_test = np.stack(X_test)[..., None]
X_test.shape
# Out:
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 180 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=10)]: Done 430 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=10)]: Done 780 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=10)]: Done 1230 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=10)]: Done 1783 out of 1783 | elapsed:    4.9s finished
# (1783, 96, 96, 1)

# %%
# standardize test dataset
X_test_norm=X_test[:,:,:,:]
X_test_norm=X_test_norm.reshape([1783,96*96,1])
# mu=x_train_norm.mean()
# sigma=x_train_norm.std()
X_test_norm=(X_test_norm - mu)/sigma
X_test_norm=X_test_norm.reshape([1783,96,96,1])

# %%
# make prediction
pred = model.predict(X_test_norm)

# %%
# this submission requires looking up
# IdLookUpTable provided by Kaggle
# every 30 rows (rowId) are considered one image
lookid_list = list(lookid_data['FeatureName'])
imageID = list(lookid_data['ImageId']-1)
pre_list = list(pred)
rowid=list(lookid_data['RowId'])

# index of each feature is extracted
feature = []
for f in list(lookid_data['FeatureName']):
    feature.append(lookid_list.index(f))

# as per imageID and feature index,
# values from predction is extracted,
# and appended to a list 'preded'
# pred[0][0] ==> ~66 ==> 1st image, 1st feature(left eye center x)
preded = []
for x,y in zip(imageID,feature):
    preded.append(pre_list[x][y])

# rowid converted to dataframe
rowid = pd.Series(rowid, name = 'RowId')
# features converted to dataframe
loc = pd.Series(preded, name = 'Location')
# rowid, and loc dataframes are concated
submission = pd.concat([rowid,loc],axis = 1)

# %%
# save submission file
submission.to_csv('../data/predictions/face_9_cb_bias.csv',index = False)

# %%
submission.head()
# Out:
#    RowId   Location
# 0      1  65.246803
# 1      2  37.607620
# 2      3  30.002489
# 3      4  36.501545
# 4      5  59.852516

# %% [markdown]
# # ASSESSMENT

# %% [markdown]
# ![face_9_result](https://user-images.githubusercontent.com/44990492/56116789-a985c380-5fa1-11e9-939f-f2756dc09a7b.png)
#
#     note: 3 dense network did 4.1
#     adding CNN + Normalization + CALLBACK improved it to 3.8
#     adding BIAS improved it to 3.1
#
#     face_7 (w/o bias):
#         loss: 6.3249 - mean_absolute_error: 1.7404
#         val_loss: 6.9588 - val_mean_absolute_error: 1.8378
#
#     face_8 (w bias):
#         loss: 1.8949 - mean_absolute_error: 0.6170
#         val_loss: 3.7994 - val_mean_absolute_error: 1.0542

# %% [markdown]
# ![face_7_loss_graph](https://user-images.githubusercontent.com/44990492/56116942-fd90a800-5fa1-11e9-88ea-3c4fda0646dc.png)
#
# ![face_8_loss_graph](https://user-images.githubusercontent.com/44990492/56116945-fd90a800-5fa1-11e9-8dda-59f954bf73dc.png)
#
# ![face_9_loss_graph](https://user-images.githubusercontent.com/44990492/56116946-fd90a800-5fa1-11e9-9cd9-157236bad03c.png)
#
#     It seems adding bias does stablize the loss (activation function).
#     Model with bias have comparably lower loss - although the cause
#     could be the random weight value;
#     graph does show that model without bias started above 400.
